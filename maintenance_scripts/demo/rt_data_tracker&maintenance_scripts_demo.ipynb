# %% [markdown]
# # Demo 1: Track Dev Branch Commits
# - Extract single file daily & parse
# - Client makes a direct request for rt.sh from GitHub
# - rt.sh is read, preprocessed & extracts the timestamps of the relevant datasets which has been pushed on GitHub.
# - Generates a file containing the datasets' timestamps
# - Program will compare the last log file with the most recent file containing the datasets' timestamps.
#
# ### Pre-requisite: Set Conda Environment
# Once you have conda installed on your machine, perform the following to create a conda environment:
# - Create environment with .yml. Note: Environment name is set within the yml file
#     - $ conda env create -f data_maintenance_env.yml
#
# - Activate the new environment via:
#    - $ conda activate data_maintenance_env
#
# - Verify that the new environment was installed correctly via:
#     - $ conda info --env
#
# - Confirm the data_maintenance_env.yml dependencies were installed via:
#     - $ conda list

# %%
from rt_revision_tracker import *

# Restart the accumulation of timestamps.
rt_revision_tracker().reset_tracker()

# %%
from rt_revision_tracker import *

# Accumulation of timestamps since time of reset.
data_log_dict = rt_revision_tracker().populate()
data_log_dict

# %% [markdown]
# #### Findings:
# - BL dataset timestamps will not necessarily sync up with the date at which PR was approved - could take unknown N days to approve.
#
# - Current practice of GitHub labels signifying a baseline change ("Baseline change" label) does not necessarily ensure timestamp date was actually change
#
# - 'BM_IC' # IC folder's prefix
#
# - 'develop' # Baseline folder's prefix
#
# - 'input-data' # Input folder's prefix
#
# - 'WW3_input_data' # WW3 Input folder's prefix
#
# #### Suggestion:
# - Why not name the datasets based on the date at which they were approved? Would allow a script to collect based on PR approved date - assuming baseline github labels are properly labeled.

# %% [markdown]
# # Demo 2: Filter Window Featuring Latest N Months (e.g. 2 Months)

# %%
# Define Window to Filter dataset by retrieval date duration
# In this scenario, capturing the past 60 days of data.
from rt_tracker_filter import RtTrackerFilter
linked_home_dir = "/home/schin"
orion_rt_data_dir = "/work/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
hera_rt_data_dir = "/scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/"
maintenance_wrapper =  RtTrackerFilter(linked_home_dir, hera_rt_data_dir)
maintenance_wrapper.maintenance_window(60)
# Out:
# All Primary Dataset Folders & Files In Main Directory (/home/schin/work/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/):
# ['develop-20220629', 'develop-20220613', 'develop-20220805', 'ufs-public-release-v2-20210212', 'develop-20220623', 'adjust_permissions.sh', 'ufs-public-release-v2-20210208', 'BM_IC-20220207', 'develop-20220316', 'develop-20220720', 'develop-20220722', 'develop-20220713', 'develop-20220707', 'develop-20220601', 'develop-20220425', 'develop-20220719', 'develop-20220616', 'input-data-20220414', 'develop-20220701', 'BM_IC-20210717', 'develop-20220729', 'develop-20220706']
#
# Data Tracker's Latest Set of Timestamped Datasets Retrieved was on 08-12-2022:
# {'BL_DATE': ['20220805'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}
#
# Data Tracker's Retrieval Dates:
# dict_keys(['06-30-2022', '07-05-2022', '07-07-2022', '07-13-2022', '07-15-2022', '07-19-2022', '07-20-2022', '07-21-2022', '07-26-2022', '07-27-2022', '07-29-2022', '08-03-2022', '08-04-2022', '08-09-2022', '08-11-2022', '08-12-2022'])
#
# Data Tracker's Log of Timestamped Datasets (By Retrieval Date):
# {'06-30-2022': {'BL_DATE': ['20220623', '20220629'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220418'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-05-2022': {'BL_DATE': ['20220701'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220418'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-07-2022': {'BL_DATE': ['20220706'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-13-2022': {'BL_DATE': ['20220707'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-15-2022': {'BL_DATE': ['20220713'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-19-2022': {'BL_DATE': ['20220713'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-20-2022': {'BL_DATE': ['20220719'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-21-2022': {'BL_DATE': ['20220720'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-26-2022': {'BL_DATE': ['20220722'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-27-2022': {'BL_DATE': ['20220722'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-29-2022': {'BL_DATE': ['20220722'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '08-03-2022': {'BL_DATE': ['20220729'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '08-04-2022': {'BL_DATE': ['20220729'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '08-09-2022': {'BL_DATE': ['20220805'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '08-11-2022': {'BL_DATE': ['20220805'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '08-12-2022': {'BL_DATE': ['20220805'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}}
#
# Latest Datasets Retrieved on 08-12-2022:
# {'06-30-2022': (['input-data-20220414'], ['develop-20220623', 'develop-20220629'], ['WW3_input_data_20220418'], ['BM_IC-20220207']), '07-05-2022': (['input-data-20220414'], ['develop-20220701'], ['WW3_input_data_20220418'], ['BM_IC-20220207']), '07-07-2022': (['input-data-20220414'], ['develop-20220706'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-13-2022': (['input-data-20220414'], ['develop-20220707'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-15-2022': (['input-data-20220414'], ['develop-20220713'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-19-2022': (['input-data-20220414'], ['develop-20220713'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-20-2022': (['input-data-20220414'], ['develop-20220719'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-21-2022': (['input-data-20220414'], ['develop-20220720'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-26-2022': (['input-data-20220414'], ['develop-20220722'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-27-2022': (['input-data-20220414'], ['develop-20220722'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '07-29-2022': (['input-data-20220414'], ['develop-20220722'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '08-03-2022': (['input-data-20220414'], ['develop-20220729'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '08-04-2022': (['input-data-20220414'], ['develop-20220729'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '08-09-2022': (['input-data-20220414'], ['develop-20220805'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '08-11-2022': (['input-data-20220414'], ['develop-20220805'], ['WW3_input_data_20220624'], ['BM_IC-20220207']), '08-12-2022': (['input-data-20220414'], ['develop-20220805'], ['WW3_input_data_20220624'], ['BM_IC-20220207'])}
#
# Latest Retrieved Datasets' File Directories:
# defaultdict(<class 'dict'>, {'INPUTDATA_ROOT': {'input-data-20220414': ['input-data-20220414/WW3_input_data_20220624/mesh.glo_1deg.nc', 'input-data-20220414/WW3_input_data_20220624/mod_def.pointsatmw', 'input-data-20220414/WW3_input_data_20220624/mod_def.glo_15mxt', 'input-data-20220414/WW3_input_data_20220624/mod_def.gsh_15m', 'input-data-20220414/WW3_input_data_20220624/mod_def.mx100', 'input-data-20220414/WW3_input_data_20220624/mesh.gwes_30m.nc', 'input-data-20220414/WW3_input_data_20220624/mod_def.natl_6m', 'input-data-20220414/WW3_input_data_20220624/mod_def.glo_1deg', 'input-data-20220414/WW3_input_data_20220624/mod_def.mx050', 'input-data-20220414/WW3_input_data_20220624/mod_def.aoc_9km', 'input-data-20220414/WW3_input_data_20220624/mod_def.mx025', 'input-data-20220414/WW3_input_data_20220624/mod_def.points', 'input-data-20220414/WW3_input_data_20220624/rmp_src_to_dst_conserv_002_001.nc', 'input-data-20220414/WW3_input_data_20220624/mod_def.gwes_30m', 'input-data-20220414/WW3_input_data_20220624/wind.natl_6m', 'input-data-20220414/WW3_input_data_20220624/mesh.hafs.nc', 'input-data-20220414/WW3_input_data_20220624/rmp_src_to_dst_conserv_003_001.nc', 'input-data-20220414/WW3_input_data_20220624/mod_def.mx025lite', 'input-data-20220414/WW3_input_data_20220624/mod_def.gnh_10m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_15mxt', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.ant_9km', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_2deg', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025obs0', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_5deg', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_1deg', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gwes_30m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.points', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx100obs0', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/machine-setup.sh', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gnh_10m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/creategridfiles.sh', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_30m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gsh_15m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025lite', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_10m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.aoc_9km', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.natl_6m', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.pointsatmw', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx050obs0', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx050', 'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx100', 'input-data-20220414/fv3_regional_c768/INPUT/grid.tile7.halo4.nc', 'input-data-20220414/fv3_regional_c768/INPUT/oro_data.tile7.halo4.nc', 'input-data-20220414/fv3_regional_c768/INPUT/sfc_data.nc', 'input-data-20220414/fv3_regional_c768/INPUT/gfs_ctrl.nc', 'input-data-20220414/fv3_regional_c768/INPUT/C768_grid.tile7.nc', 'input-data-20220414/fv3_regional_c768/INPUT/C768_oro_data.tile7.halo4.nc', 'input-data-20220414/fv3_regional_c768/INPUT/gfs_data.nc', 'input-data-20220414/fv3_regional_c768/INPUT/C768_mosaic.nc', 'input-data-20220414/fv3_regional_c768/INPUT/grid_spec.nc', 'input-data-20220414/fv3_regional_c768/INPUT/sfc_data.tile7.nc', 'input-data-20220414/fv3_regional_c768/INPUT/gfs_data.tile7.nc', 'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.000.nc', 'input-data-20220414/fv3_regi ...
#
# Start Date of Window of Interest: 06-18-2022
# All UFS-WM RT Cloud Data are w/in Requested Window (Latest 60 Days)!
