# %% [markdown]
# # Demo: Data Uploader for UFS Datasets to Cloud Data Storage
#
# ### __Purpose:__
#
# The purpose of this program is to transfer the Unified Forecast Sytstem (UFS) input and baseline datasets residing within the RDHPCS to cloud data storage via chaining API calls to communicate with cloud data storage buckets. The program will support the data required for the current UFS Weather Model (UFS WM) deployed within the RDHPCS as well as support the NOAA development team's data management in maintaining only the datasets committed within the latest N months of their UFS development code (once the program is integrated into Jenkins).
#
# According to Amazon AWS, the following conditions need to be considered when transferring data to cloud data storage:
# - Largest object that can be uploaded in a single PUT is 5 GB.
# - Individual Amazon S3 objects can range in size from a minimum of 0 bytes to a maximum of 5 TB.
# - For objects larger than 100 MB, Amazon recommends using the Multipart Upload capability.
# - The total volume of data in a cloud data storage bucket are unlimited.
#
# Tools which could be be utilized to perform data transferring & partitioning (Multipart Upload/Download) are:
# - AWS SDK
# - AWS CLI
# - AWS S3 REST API
#
# All of the AWS provided tools are built on Boto3.
#
# In this demontration, the framework will implement Python AWS SDK for transferring the UFS datasets from the RDHPCS, Orion, to the cloud data storage with low latency.
#
# The AWS SDK will be implemented for the following reasons:
# - To integrate with other python scripts.
# - AWS SDK carries addition capabilities/features for data manipulation & transferring compare to the aforementioned alternate tools.
#
# ### __Capabilities:__
#
# The framework will be able to perform the following actions:
#
# - Multi-threading & partitioning to the datasets to assist in the optimization in uploading performance of the datasets from on-prem to cloud.
#
# ### __Future Capabilities:__
#
# The program can be used as a skeletal framework for transferring future datasets of interest (e.g. SRW data, MRW data, etc). In addition, it can be integrated with the UFS tracker bot (https://github.com/NOAA-EPIC/ufs-dev_data_timestamps) & Jenkins to automate the data transferring process as new datasets are being committed & pushed to the UFS-WM repository develop branch.
#
#
# ### __Sample Datasets to Transfer:__
# There are two scenarios that will need to be considered when storing the UFS data in cloud:
#
# - Datasets to be stored in cloud need to support NOAA's development team. Datasets residing within the Cloud as well as RDHPCS must support their development team's latest 2 months of developing code.
#
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports NOAA Dev Team Versons (since 03-04-22)| 20220304 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207
# | Supports NOAA Dev Team Versons (since 03-16-22)| 20220316 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versons (since 03-18-22)| 20220318 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versions (since 03-18-22)| 20220321 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
# | Supports NOAA Dev Team Versions (since 03-18-29)| 20220329 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
#
# - Datasets to be stored need to support the UFS weather model develop branch code revision, which was pulled last year October 2021 by the EPIC's Platform team. These datasets are:
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports UFS Model Version Deployed in CSPs| 20220207 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20210717 |
#
# <img src="./images/DataVersionsZach&JongAreUsing.png">
#
# ### __Environment Setup:__
#
# 1. Install miniconda on your machine. Note: Miniconda is a smaller version of Anaconda that only includes conda along with a small set of necessary and useful packages. With Miniconda, you can install only what you need, without all the extra packages that Anaconda comes packaged with:
#
# Download latest Miniconda (e.g. 3.9 version):
# - __wget https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Check integrity downloaded file with SHA-256:
# - __sha256sum Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Reference SHA256 hash in following link: https://docs.conda.io/en/latest/miniconda.html
#
# Install Miniconda in Linux:
# - __bash Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Next, Miniconda installer will prompt where do you want to install Miniconda. Press ENTER to accept the default install location i.e. your $HOME directory. If you don't want to install in the default location, press CTRL+C to cancel the installation or mention an alternate installation directory. If you've chosen the default location, the installer will display “PREFIX=/var/home/<user>/miniconda3” and continue the installation.
#
# For installation to take into effect, run the following command:
# - __source ~/.bashrc__
#
# Next, you will see the prefix (base) in front of your terminal/shell prompt. Indicating the conda's base environment is activated.
#
# 2.	Once you have conda installed on your machine, perform the following to create a conda environment:
#
# To create a new environment (if a YAML file is not provided)
# - __conda create -n [Name of your conda environment you wish to create]__
#
# __(OR)__
#
# To ensure you are running Python 3.9:
# - __conda create -n myenv Python=3.9__
#
# __(OR)__
#
# To create a new environment from an existing YAML file (if a YAML file is provided):
# - __conda env create -f environment.yml__
#
# __*Note:__ A .yml file is a text file that contains a list of dependencies, which channels a list for installing dependencies for the given conda environment. For the code to utilize the dependencies, you will need to be in the directory where the environment.yml file lives.
#
# 4.	Activate the new environment via:
# - __conda activate [Name of your conda environment you wish to activate]__
#
# 5.	Verify that the new environment was installed correctly via:
# - __conda info --env__
#
# __*Note:__
# - From this point on, must activate conda environment prior to .py script(s) or jupyter notebooks execution
# using the following command: __conda activate__
# - To deactivate a conda environment:
#     - __conda deactivate__
#
# #### ___Link Home Directory to Dataset Location on RDHPCS Platform___
#
# 6.	Unfortunately, there is no way to navigate to the /work/ filesystem from within the Jupyter interface. The best way to workaround is to create a symbolic link in your home folder that will take you to the /work/ filesystem. Run the following command from a linux terminal on Orion to create the link:
#
#     - __ln -s /work /home/[Your user account name]/work__
#
# Now, when you navigate to the __/home/[Your user account name]/work__ directory in Jupyter, it will take you to the __/work__ folder. Allowing you to obtain any data residing within the __/work__ filesystem that you have permission to access from Jupyter. This same procedure will work for any filesystem available from the root directory.
#
# __*Note:__ On Orion, user must sym link from their home directory to the main directory containing the datasets of interest.
#
# #### ___Open & Run Data Analytics Tool on Jupyter Notebook___
#
# 7.	Open OnDemand has a built-in file explorer and file transfer application available directly from its dashboard via ...
#     - Login to https://orion-ood.hpc.msstate.edu/
#     - In the Open OnDemand Interface, select __Interactive Apps__ > __Jupyter Notbook__
#     - Set the following configurations to run Jupyter:
#
#
# #### ___Additonal Information___
#
# __To create a .yml file, execute the following commands:__
#
# - Activate the environment to export:
#     - __conda activate myenv__
#
# - Export your active environment to a new file:
#     - __conda env export > [ENVIRONMENT FILENAME].yml__
#
#
# ### __Reference(s)__
# Latest UFS Weather Model Guide:
# - https://ufs-weather-model.readthedocs.io/en/latest/InputsOutputs.html

# %% [markdown]
# # Demo 1: Data Locality Extractor from Source
#
# #### Test Sample
# The script will read from the data tracker bot's output pickle file. The test sample generated by the data tracker bot will reside in **./data_from_ts_tracker/latest_rt.sh.pk** at this time until Jenkins is connected to the RDHPCS.
#
# In this demonstration, datasets were transferred to the cloud data storage to support the following developing UFS-WMs of interest.
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports UFS Model Version Deployed in CSPs| 20220207 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20210717 |
# | Supports NOAA Dev Team Versons (since 03-04-22)| 20220304 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207
# | Supports NOAA Dev Team Versons (since 03-16-22)| 20220316 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versons (since 03-18-22)| 20220318 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versions (since 03-18-22)| 20220321 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
# | Supports NOAA Dev Team Versions (since 03-18-29)| 20220329 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|

# %% [markdown]
# ### Obtain directories for the datasets tracked by the data tracker bot.
#
# **TODO: FOR YEAR 2, will capture the date at which the ts were extracted and then write a script which will add a sliding filter window to capture only the latest 2 months of development code.

# %%
if __name__ == '__main__': 
    
    # Module for extracting data from source.
    from get_timestamp_data import GetTimestampData
    
    # Establish locality of where the dataseta are sourced.
    linked_home_dir = "/home/schin"
    orion_rt_data_dir = linked_home_dir + "/work/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
    hera_rt_data_dir = "/scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/"
    
    # Read data tracker's latest set of timestamps retrieved
    get_ts_wrapper = GetTimestampData(hera_rt_data_dir, None) #CHANGED
    latest_retrieved_ts = get_ts_wrapper.data_log_dict

    # Filter to tracker log's timestamps & extract their corresponding UFS input & baseline file directories.
    filter2tracker_ts_datasets = get_ts_wrapper.get_tracker_ts_files()
# Out:
# All Primary Dataset Folders & Files In Main Directory (/scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/):
# ['develop-20221121', 'develop-20220907', 'develop-20221101', 'input-data-20220414', 'develop-20220830', 'input-data-20211210', 'develop-20220909', 'develop-20220722', 'develop-20221108', 'develop-20220729', 'develop-20221107', 'input-data-20211203', 'develop-20220912', 'develop-20220929', 'develop-20220720', 'develop-20221026', 'develop-20220919', 'develop-20220719', 'develop-20221012', 'develop-20221017', 'prototype7-input-data-20210608', 'adjust_permissions.sh', 'develop-20221007', '_develop-20221021', 'develop-20221110', 'develop-20220805', 'develop-20221028', 'input-data-20221101', 'BM_IC-20220207', 'develop-20221116', 'develop-20221024', 'develop-20220829', 'ufs-public-release-20200728']
#
# Data Tracker's Latest Set of Timestamped Datasets Retrieved was on 07-12-2022:
# {'BL_DATE': ['20221119'], 'INPUTDATA_ROOT': ['20211112'], 'INPUTDATA_ROOT_WW3': ['20211113'], 'INPUTDATA_ROOT_BMIC': ['20220214']}
#
# Data Tracker's Retrieval Dates:
# dict_keys(['07-12-2022'])
#
# Data Tracker's Log of Timestamped Datasets (By Retrieval Date):
# {'07-12-2022': {'BL_DATE': ['20221119'], 'INPUTDATA_ROOT': ['20211112'], 'INPUTDATA_ROOT_WW3': ['20211113'], 'INPUTDATA_ROOT_BMIC': ['20220214']}}
#
# Latest Datasets Retrieved on 07-12-2022:
# {'07-12-2022': (['input-data-20211112'], ['develop-20221119'], ['WW3_input_data_20211113'], ['BM_IC-20220214'])}

# %%
# Confirm: Keys of latest Retrieval Date Tracked by Data Tracker Bot
filter2tracker_ts_datasets.keys()
# Out:
# dict_keys(['INPUTDATA_ROOT_WW3'])

# %%
# Selected timestamp dataset of the latest rettrival date to transfer 
# from RDHPCS on-disk to cloud as tracked by data tracker bot
filter2tracker_ts_datasets
# Out:
# defaultdict(dict,
#             {'INPUTDATA_ROOT_WW3': {'WW3_input_data_20211113': ['input-data-20220414/WW3_input_data_20211113/mod_def.mx050',
#                'input-data-20220414/WW3_input_data_20211113/rmp_src_to_dst_conserv_002_001.nc',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_2deg',
#                'input-data-20220414/WW3_input_data_20211113/wind.natl_6m',
#                'input-data-20220414/WW3_input_data_20211113/mesh.hafs.nc',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.gnh_10m',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.points',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_15mxt',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_1deg',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.gsh_15m',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_30m',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.gwes_30m',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.ant_9km',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.aoc_9km',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.mx025',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.natl_6m',
#                'input-data-20220414/WW3_input_data_20211113/rmp_src_to_dst_conserv_003_001.nc',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_10m',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.glo_5deg',
#                'input-data-20220414/WW3_input_data_20211113/mesh.glo_1deg.nc',
#                'input-data-20220414/WW3_input_data_20211113/mod_def.mx100',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_2deg',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/creategridfiles.sh',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gwes_30m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_10m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gsh_15m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.points',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.aoc_9km',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_15mxt',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_5deg',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.natl_6m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_30m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.ant_9km',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gnh_10m',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_1deg',
#                'input-data-20220414/WW3_input_data_20211113/createmoddefs/machine-setup.sh',
#                'input-data-20211210/WW3_input_data_20211113/rmp_src_to_dst_conserv_002_001.nc',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_2deg',
#                'input-data-20211210/WW3_input_data_20211113/wind.natl_6m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.gnh_10m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.points',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_15mxt',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_1deg',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.gsh_15m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_30m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.gwes_30m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.ant_9km',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.aoc_9km',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.natl_6m',
#                'input-data-20211210/WW3_input_data_20211113/rmp_src_to_dst_conserv_003_001.nc',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_10m',
#                'input-data-20211210/WW3_input_data_20211113/mod_def.glo_5deg',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_2deg',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/creategridfiles.sh',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gwes_30m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_10m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gsh_15m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.points',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.aoc_9km',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_15mxt',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_5deg',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.natl_6m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_30m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.ant_9km',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gnh_10m',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_1deg',
#                'input-data-20211210/WW3_input_data_20211113/createmoddefs/machine-setup.sh',
#                'input-data-20211203/WW3_input_data_20211113/rmp_src_to_dst_conserv_002_001.nc',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_2deg',
#                'input-data-20211203/WW3_input_data_20211113/wind.natl_6m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.gnh_10m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.points',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_15mxt',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_1deg',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.gsh_15m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_30m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.gwes_30m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.ant_9km',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.aoc_9km',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.natl_6m',
#                'input-data-20211203/WW3_input_data_20211113/rmp_src_to_dst_conserv_003_001.nc',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_10m',
#                'input-data-20211203/WW3_input_data_20211113/mod_def.glo_5deg',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_2deg',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/creategridfiles.sh',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gwes_30m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_10m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gsh_15m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.points',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.aoc_9km',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_15mxt',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_5deg',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.natl_6m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_30m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.ant_9km',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.gnh_10m',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_1deg',
#                'input-data-20211203/WW3_input_data_20211113/createmoddefs/machine-setup.sh']}})

# %% [markdown]
# ### Obtain directories for the datasets requested by the user.
# TODO: SYNC last 20220701 baseline data on 8/15/22

# %%
# if __name__ == '__main__': 
    
#     # Module for extracting data from source.
#     from get_timestamp_data import GetTimestampData
    
#     # Establish locality of where the dataseta are sourced.
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
    
#     # Select timestamp dataset to transfer from RDHPCS on-disk to cloud
#     input_ts, bl_ts, ww3_input_ts, bmic_ts = [], ['develop-20220701'], [], []
#     filter2specific_ts_datasets = GetTimestampData(orion_rt_data_dir, None).get_specific_ts_files(input_ts, bl_ts, ww3_input_ts, bmic_ts)
# filter2specific_ts_datasets.keys()

# %%
# # Selected timestamp dataset to transfer from RDHPCS on-disk to cloud
# filter2specific_ts_datasets['BL_DATE']

# %% [markdown]
# # Demo 2: Multipart Upload of Extracted Data to Cloud

# %% [markdown]
# ### Upload datasets tracked by the data tracker bot.

# %%
# if __name__ == '__main__': 
    
#     # Transfers latest timestamped dataset(s) which do not currently reside in cloud.
#     from transfer_bot_data import TransferBotData
#     TransferBotData(linked_home_dir, orion_rt_data_dir)

# %% [markdown]
# ### Upload datasets by timestamps as requested by the user.
# - In this scenario, used when transferring data files required for the UFS-WM currently deployed in the CSPs.

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, filter2specific_ts_datasets, use_bucket='rt')
#     uploader_wrapper.upload_files2cloud()

# %% [markdown]
# # Consolidated Demo: Extract Data Localities & Upload to Cloud

# %% [markdown]
# ### Extract & upload datasets (input data + baseline data + IC data) as requested by the user.

# %%
# Obtain directories & upload to cloud for the datasets requested by the user.
from transfer_specific_data import TransferSpecificData
input_ts, bl_ts, ww3_input_ts, bmic_ts = [], [], [], ['BM_IC-20220207']
#TransferSpecificData(input_ts, bl_ts, ww3_input_ts, bmic_ts, linked_home_dir, orion_rt_data_dir)
TransferSpecificData(input_ts, bl_ts, ww3_input_ts, bmic_ts, None, hera_rt_data_dir)
# Out:
# All Primary Dataset Folders & Files In Main Directory (/scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/):
# ['develop-20221121', 'develop-20220907', 'develop-20221101', 'input-data-20220414', 'develop-20220830', 'input-data-20211210', 'develop-20220909', 'develop-20220722', 'develop-20221108', 'develop-20220729', 'develop-20221107', 'input-data-20211203', 'develop-20220912', 'develop-20220929', 'develop-20220720', 'develop-20221026', 'develop-20220919', 'develop-20220719', 'develop-20221012', 'develop-20221017', 'prototype7-input-data-20210608', 'adjust_permissions.sh', 'develop-20221007', '_develop-20221021', 'develop-20221110', 'develop-20220805', 'develop-20221028', 'input-data-20221101', 'BM_IC-20220207', 'develop-20221116', 'develop-20221024', 'develop-20220829', 'ufs-public-release-20200728']
#
# Data Tracker's Latest Set of Timestamped Datasets Retrieved was on 07-12-2022:
# {'BL_DATE': ['20221119'], 'INPUTDATA_ROOT': ['20211112'], 'INPUTDATA_ROOT_WW3': ['20211113'], 'INPUTDATA_ROOT_BMIC': ['20220214']}
#
# Data Tracker's Retrieval Dates:
# dict_keys(['07-12-2022'])
#
# Data Tracker's Log of Timestamped Datasets (By Retrieval Date):
# {'07-12-2022': {'BL_DATE': ['20221119'], 'INPUTDATA_ROOT': ['20211112'], 'INPUTDATA_ROOT_WW3': ['20211113'], 'INPUTDATA_ROOT_BMIC': ['20220214']}}
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/get_p8c.sh  421 / 421.0  (100.00%)Processing Time (min): 0.005755885442097982
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.1070092995961507
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.2589190363883972
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.22934377193450928
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.030049681663513184
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009813507397969563
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23059213956197103
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.024902216593424478
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.029524505138397217
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03235046068827311
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.029181528091430663
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.025109469890594482
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0214752395947775
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.24168923298517864
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.11595750252405802
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.1267363905906677
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.1791777809460958
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.06210247675577799
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0008904099464416504
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0204162359237672
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.01072471539179484
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.011503255367279053
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.011664919058481852
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.011274357636769613
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.011119441191355387
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 2.022306489944458
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0215148250261943
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/wav_p7.2/gwes_30m/20130401.000000.restart.gwes_30m  822130560 / 822130560.0  (100.00%)Processing Time (min): 0.10935074885686238
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.21747718254725137
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.23076643149058024
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.24960952599843342
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.039794389406840006
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0022167007128397623
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.36742098331451417
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.09734129110972087
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.04550071159998576
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.04357877969741821
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.033245400587717695
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03223718404769897
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.0204468329747518
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 2.0224531491597495
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23529941240946453
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.234610112508138
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23910582065582275
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.034656417369842527
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0011319239934285481
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.24750478665033976
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.04583394924799601
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.037107829252878824
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03547351360321045
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02877073287963867
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02664413054784139
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0245810190836588
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0242842078208922
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/mom6_da/MOM.res_3.nc  3782305532 / 3782305532.0  (100.00%)Processing Time (min): 0.3170117656389872
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/mom6_da/MOM.res.nc  3732528411 / 3732528411.0  (100.00%)Processing Time (min): 0.3781823992729187
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/mom6_da/MOM.res_4.nc  970483240 / 970483240.0  (100.00%)Processing Time (min): 0.09805779457092285
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/mom6_da/MOM.res_1.nc  3769864280 / 3769864280.0  (100.00%)Processing Time (min): 0.319719123840332
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/mom6_da/MOM.res_2.nc  3832073508 / 3832073508.0  (100.00%)Processing Time (min): 0.3131611943244934
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/wav_p8c/mx025/20130401.000000.restart.ww3  6989666400 / 6989666400.0  (100.00%)Processing Time (min): 0.6354682604471843
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/wav_p8c/mx025/20130401.000000.restart.mx025  6989666400 / 6989666400.0  (100.00%)Processing Time (min): 0.5795407652854919
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013040100/cpc/cice5_model_0.25.res_2013040100.nc  1916010176 / 1916010176.0  (100.00%)Processing Time (min): 0.21994131406148273
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.26600923935572307
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.2410479466120402
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.30056991974512737
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.07129933436711629
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.00142438014348348
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.26738574107487995
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.04124340216318766
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.16330054998397828
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.07503270705540975
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.039174373944600424
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02940314213434855
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0293161670366924
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.32561906178792316
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 2.0207696080207826
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0218369404474894
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.13449612458546956
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.04128568172454834
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0014708399772644042
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.14217610359191896
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.04901703993479411
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.03722070455551148
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.029143699010213218
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.025930078824361165
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.02346201737721761
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.1436721404393514
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.10849090417226155
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/wav_p7.2/gwes_30m/20130101.000000.restart.gwes_30m  822130560 / 822130560.0  (100.00%)Processing Time (min): 0.08456500768661498
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.3438850204149882
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 2.0214581290880838
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.23483195702234905
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.032171912988026935
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009265462557474772
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.2237831672032674
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.020585147539774577
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.01754102309544881
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.016241014003753662
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.017406415939331055
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.015704413255055744
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.0284040451049805
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.0264366388320922
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0230923771858216
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23519567648569742
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23860996961593628
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.031281328201293944
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009473443031311035
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.22825942834218343
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.030183724562327065
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.025250407059987386
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.023008227348327637
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.022194290161132814
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02350747585296631
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 3.0211899717648825
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.29343079725901283
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/mom6_da/MOM.res_3.nc  3782305532 / 3782305532.0  (100.00%)Processing Time (min): 0.3284187912940979
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/mom6_da/MOM.res.nc  3732528411 / 3732528411.0  (100.00%)Processing Time (min): 0.3015607436498006
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/mom6_da/MOM.res_4.nc  970483240 / 970483240.0  (100.00%)Processing Time (min): 0.08372188011805216
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/mom6_da/MOM.res_1.nc  3769864280 / 3769864280.0  (100.00%)Processing Time (min): 0.3625665585199992
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/mom6_da/MOM.res_2.nc  3832073508 / 3832073508.0  (100.00%)Processing Time (min): 0.33442501227060956
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/wav_p8c/mx025/20130101.000000.restart.mx025  6989666400 / 6989666400.0  (100.00%)Processing Time (min): 0.6549521605173747
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2013010100/cpc/cice5_model_0.25.res_2013010100.nc  1916010176 / 1916010176.0  (100.00%)Processing Time (min): 0.2042808214823405
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.2476972262064616
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.24901387294133503
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23834619522094727
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03501946528752645
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.000993319352467855
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.2456399401028951
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.04484220345815023
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.033708715438842775
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.028836909929911295
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02822492520014445
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.02432097593943278
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.1524870196978252
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.21834579706192017
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.15580891370773314
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.19798945188522338
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc  784105472 / 1137998431.0  (68.90%)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.22986600796381632
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.12152066628138224
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009174863497416178
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0214197317759195
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.009452621142069498
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.015506478150685628
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.010702025890350342
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.018903128306070962
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc  55490326 / 55490326.0  (100.00%)Processing Time (min): 0.018547741572062175
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0310841917991638
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 1.0277382731437683
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/wav_p7.2/gwes_30m/20120401.000000.restart.gwes_30m  822130560 / 822130560.0  (100.00%)Processing Time (min): 1.0205360174179077
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.0197762966156005
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.022728153069814
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 1.0244833747545878
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.012362368901570638
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009949882825215659
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 3.0236048499743142
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.009901189804077148
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.011164859930674235
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.009741799036661784
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.011201310157775878
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.010039409001668295
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.22685632308324177
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc  2723466311 / 2723466311.0  (100.00%)Processing Time (min): 0.2260664661725362
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23952453931172688
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.27635482549667356
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.251497757434845
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03884443442026774
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0016492486000061035
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.2517475366592407
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.037081412474314374
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03013061285018921
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.027456510066986083
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.023751155535380045
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.022210939725240072
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.25193803310394286
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.30365904569625857
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/mom6_da/MOM.res_3.nc  3782305532 / 3782305532.0  (100.00%)Processing Time (min): 0.315326730410258
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/mom6_da/MOM.res.nc  3732528411 / 3732528411.0  (100.00%)Processing Time (min): 0.43042905728022257
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/mom6_da/MOM.res_4.nc  970483240 / 970483240.0  (100.00%)Processing Time (min): 0.08876784642537434
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/mom6_da/MOM.res_1.nc  3769864280 / 3769864280.0  (100.00%)Processing Time (min): 0.31835304101308187
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/mom6_da/MOM.res_2.nc  3832073508 / 3832073508.0  (100.00%)Processing Time (min): 0.40068663358688356
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/wav_p8c/mx025/20120401.000000.restart.mx025  6989666400 / 6989666400.0  (100.00%)Processing Time (min): 0.6397328019142151
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012040100/cpc/cice5_model_0.25.res_2012040100.nc  1916010176 / 1916010176.0  (100.00%)Processing Time (min): 0.18700017929077148
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile1.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23952868779500325
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile6.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.22244810263315837
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile5.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23631457487742105
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile5.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.030150389671325682
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_ctrl.nc  8553 / 8553.0  (100.00%)Processing Time (min): 0.0009151895840962728
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile4.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 0.23231590986251832
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile1.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03906772931416829
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile3.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.031794500350952146
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile4.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.0280032475789388
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile2.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.03103803793589274
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/sfc_data.tile6.nc  55490435 / 55490435.0  (100.00%)Processing Time (min): 0.027848390738169353
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile3.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0360586444536846
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/p8c/C384_L127/INPUT/gfs_data.tile2.nc  2723463497 / 2723463497.0  (100.00%)Processing Time (min): 1.0252546111742655
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc  1137998431 / 1137998431.0  (100.00%)Processing Time (min): 0.20941150188446045
#
# /scratch1/NCEPDEV/nems/emc.nemspara/RT/NEMSfv3gfs/BM_IC-20220207/2012070100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc  1086798431 / 1137998431.0  (95.50%)

# %% [markdown]
# ### Extract & upload datasets tracked by the data tracker bot.

# %%
# # Obtain directories & upload to cloud for the latest retrieved set of timestamped datasets tracked by the data tracker bot.
# from transfer_bot_data import TransferBotData
# TransferBotData(linked_home_dir, orion_rt_data_dir)

# %% [markdown]
# # Demo: Upload a Single Data File of Interest

# %%
## if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
    
#     # Upload a Single Data File of Interest
#     file_dir = 'input-data-20211210/fv3_regional_c768/INPUT/grid.tile7.halo4.nc'
#     uploader_wrapper.upload_single_file(file_dir)

# %% [markdown]
# # Demo: Delete a File

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     file_dir = 'input-data-20211210/fv3_regional_c768/INPUT/grid.tile7.halo4.nc'
#     key_path = file_dir
#     uploader_wrapper.purge(key_path)

# %% [markdown]
# # Demo: Delete Objects with Key Prefix

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     key_prefix = 'develop-20220701'
#     uploader_wrapper.purge_by_keyprefix(key_prefix)

# %% [markdown]
# # Demo: Copy Objects & Delete with Key Prefix
# AWS CLI copies the objects to the target folder and then removes the original file. There is no “move” action in S3.

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     source_key_path = '####' 
#     new_key_path = '###'
#     uploader_wrapper.rename_s3_keys(source_key_path, new_key_path)

# %% [markdown]
# # Demo: Get List of All Keys in UFS RT S3 Bucket

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
    
#     # Establish locality of where the dataseta are sourced.
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
    
#     # Instantiate wrapper
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
    
#     # Determine all s3 object keys.
#     all_bucket_objects = uploader_wrapper.get_all_s3_keys()
    
# all_bucket_objects

# %%
# Write list to text file and save to directory
# with open('filename].[file_format]', 'w') as f:
#     for item in all_bucket_objects:
#         f.write("%s\n" % item)
