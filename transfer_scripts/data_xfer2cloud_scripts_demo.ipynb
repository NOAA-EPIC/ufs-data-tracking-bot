# %% [markdown]
# # Demo: Data Uploader for UFS Datasets to Cloud Data Storage
#
# ### __Purpose:__
#
# The purpose of this program is to transfer the Unified Forecast Sytstem (UFS) input and baseline datasets residing within the RDHPCS to cloud data storage via chaining API calls to communicate with cloud data storage buckets. The program will support the data required for the current UFS Weather Model (UFS WM) deployed within the RDHPCS as well as support the NOAA development team's data management in maintaining only the datasets committed within the latest N months of their UFS development code (once the program is integrated into Jenkins).
#
# According to Amazon AWS, the following conditions need to be considered when transferring data to cloud data storage:
# - Largest object that can be uploaded in a single PUT is 5 GB.
# - Individual Amazon S3 objects can range in size from a minimum of 0 bytes to a maximum of 5 TB.
# - For objects larger than 100 MB, Amazon recommends using the Multipart Upload capability.
# - The total volume of data in a cloud data storage bucket are unlimited.
#
# Tools which could be be utilized to perform data transferring & partitioning (Multipart Upload/Download) are:
# - AWS SDK
# - AWS CLI
# - AWS S3 REST API
#
# All of the AWS provided tools are built on Boto3.
#
# In this demontration, the framework will implement Python AWS SDK for transferring the UFS datasets from the RDHPCS, Orion, to the cloud data storage with low latency.
#
# The AWS SDK will be implemented for the following reasons:
# - To integrate with other python scripts.
# - AWS SDK carries addition capabilities/features for data manipulation & transferring compare to the aforementioned alternate tools.
#
# ### __Capabilities:__
#
# The framework will be able to perform the following actions:
#
# - Multi-threading & partitioning to the datasets to assist in the optimization in uploading performance of the datasets from on-prem to cloud.
#
# ### __Future Capabilities:__
#
# The program can be used as a skeletal framework for transferring future datasets of interest (e.g. SRW data, MRW data, etc). In addition, it can be integrated with the UFS tracker bot (https://github.com/NOAA-EPIC/ufs-dev_data_timestamps) & Jenkins to automate the data transferring process as new datasets are being committed & pushed to the UFS-WM repository develop branch.
#
#
# ### __Sample Datasets to Transfer:__
# There are two scenarios that will need to be considered when storing the UFS data in cloud:
#
# - Datasets to be stored in cloud need to support NOAA's development team. Datasets residing within the Cloud as well as RDHPCS must support their development team's latest 2 months of developing code.
#
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports NOAA Dev Team Versons (since 03-04-22)| 20220304 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207
# | Supports NOAA Dev Team Versons (since 03-16-22)| 20220316 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versons (since 03-18-22)| 20220318 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versions (since 03-18-22)| 20220321 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
# | Supports NOAA Dev Team Versions (since 03-18-29)| 20220329 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
#
# - Datasets to be stored need to support the UFS weather model develop branch code revision, which was pulled last year October 2021 by the EPIC's Platform team. These datasets are:
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports UFS Model Version Deployed in CSPs| 20220207 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20210717 |
#
# <img src="./images/DataVersionsZach&JongAreUsing.png">
#
# ### __Environment Setup:__
#
# 1. Install miniconda on your machine. Note: Miniconda is a smaller version of Anaconda that only includes conda along with a small set of necessary and useful packages. With Miniconda, you can install only what you need, without all the extra packages that Anaconda comes packaged with:
#
# Download latest Miniconda (e.g. 3.9 version):
# - __wget https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Check integrity downloaded file with SHA-256:
# - __sha256sum Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Reference SHA256 hash in following link: https://docs.conda.io/en/latest/miniconda.html
#
# Install Miniconda in Linux:
# - __bash Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Next, Miniconda installer will prompt where do you want to install Miniconda. Press ENTER to accept the default install location i.e. your $HOME directory. If you don't want to install in the default location, press CTRL+C to cancel the installation or mention an alternate installation directory. If you've chosen the default location, the installer will display “PREFIX=/var/home/<user>/miniconda3” and continue the installation.
#
# For installation to take into effect, run the following command:
# - __source ~/.bashrc__
#
# Next, you will see the prefix (base) in front of your terminal/shell prompt. Indicating the conda's base environment is activated.
#
# 2.	Once you have conda installed on your machine, perform the following to create a conda environment:
#
# To create a new environment (if a YAML file is not provided)
# - __conda create -n [Name of your conda environment you wish to create]__
#
# __(OR)__
#
# To ensure you are running Python 3.9:
# - __conda create -n myenv Python=3.9__
#
# __(OR)__
#
# To create a new environment from an existing YAML file (if a YAML file is provided):
# - __conda env create -f environment.yml__
#
# __*Note:__ A .yml file is a text file that contains a list of dependencies, which channels a list for installing dependencies for the given conda environment. For the code to utilize the dependencies, you will need to be in the directory where the environment.yml file lives.
#
# 4.	Activate the new environment via:
# - __conda activate [Name of your conda environment you wish to activate]__
#
# 5.	Verify that the new environment was installed correctly via:
# - __conda info --env__
#
# __*Note:__
# - From this point on, must activate conda environment prior to .py script(s) or jupyter notebooks execution
# using the following command: __conda activate__
# - To deactivate a conda environment:
#     - __conda deactivate__
#
# #### ___Link Home Directory to Dataset Location on RDHPCS Platform___
#
# 6.	Unfortunately, there is no way to navigate to the /work/ filesystem from within the Jupyter interface. The best way to workaround is to create a symbolic link in your home folder that will take you to the /work/ filesystem. Run the following command from a linux terminal on Orion to create the link:
#
#     - __ln -s /work /home/[Your user account name]/work__
#
# Now, when you navigate to the __/home/[Your user account name]/work__ directory in Jupyter, it will take you to the __/work__ folder. Allowing you to obtain any data residing within the __/work__ filesystem that you have permission to access from Jupyter. This same procedure will work for any filesystem available from the root directory.
#
# __*Note:__ On Orion, user must sym link from their home directory to the main directory containing the datasets of interest.
#
# #### ___Open & Run Data Analytics Tool on Jupyter Notebook___
#
# 7.	Open OnDemand has a built-in file explorer and file transfer application available directly from its dashboard via ...
#     - Login to https://orion-ood.hpc.msstate.edu/
#     - In the Open OnDemand Interface, select __Interactive Apps__ > __Jupyter Notbook__
#     - Set the following configurations to run Jupyter:
#
#
# #### ___Additonal Information___
#
# __To create a .yml file, execute the following commands:__
#
# - Activate the environment to export:
#     - __conda activate myenv__
#
# - Export your active environment to a new file:
#     - __conda env export > [ENVIRONMENT FILENAME].yml__
#
#
# ### __Reference(s)__
# Latest UFS Weather Model Guide:
# - https://ufs-weather-model.readthedocs.io/en/latest/InputsOutputs.html

# %% [markdown]
# # Demo 1: Data Locality Extractor from Source
#
# #### Test Sample
# The script will read from the data tracker bot's output pickle file. The test sample generated by the data tracker bot will reside in **./data_from_ts_tracker/latest_rt.sh.pk** at this time until Jenkins is connected to the RDHPCS.
#
# In this demonstration, datasets were transferred to the cloud data storage to support the following developing UFS-WMs of interest.
#
# | UFS MODEL DEVELOPMENT VERSIONS| BASELINE DATA | INPUT DATA | WW3 INPUT DATA | BM_IC |
# | :- | :- | :- | -: | :-: |
# | Supports UFS Model Version Deployed in CSPs| 20220207 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20210717 |
# | Supports NOAA Dev Team Versons (since 03-04-22)| 20220304 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207
# | Supports NOAA Dev Team Versons (since 03-16-22)| 20220316 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versons (since 03-18-22)| 20220318 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207 |
# | Supports NOAA Dev Team Versions (since 03-18-22)| 20220321 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|
# | Supports NOAA Dev Team Versions (since 03-18-29)| 20220329 | input-data-20211210  | WW3_input_data_20211113 | BM_IC-20220207|

# %% [markdown]
# ### Obtain directories for the datasets tracked by the data tracker bot.
#
# **TODO: FOR YEAR 2, will capture the date at which the ts were extracted and then write a script which will add a sliding filter window to capture only the latest 2 months of development code.

# %%
if __name__ == '__main__': 
    
    # Module for extracting data from source.
    from get_timestamp_data import GetTimestampData
    
    # Establish locality of where the dataseta are sourced.
    linked_home_dir = "/home/schin/work"
    orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
    
    # Read data tracker's latest set of timestamps retrieved
    get_ts_wrapper = GetTimestampData(orion_rt_data_dir, None)
    latest_retrieved_ts = get_ts_wrapper.data_log_dict

    # Filter to tracker log's timestamps & extract their corresponding UFS input & baseline file directories.
    filter2tracker_ts_datasets = get_ts_wrapper.get_tracker_ts_files()
# Out:
# All Primary Dataset Folders & Files In Main Directory (/home/schin/work/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/):
# ['develop-20220629', 'develop-20220613', 'develop-20220511', 'ufs-public-release-v2-20210212', 'develop-20220623', 'adjust_permissions.sh', 'ufs-public-release-v2-20210208', 'develop-20220519', 'develop-20220508', 'develop-20220517', 'BM_IC-20220207', 'develop-20220316', 'develop-20220516', 'develop-20220503', 'develop-20220707', 'develop-20220601', 'develop-20220512', 'develop-20220502', 'develop-20220425', 'develop-20220531', 'develop-20220616', 'input-data-20220414', 'develop-20220701', 'BM_IC-20210717', 'develop-20220706']
#
# Data Tracker's Latest Set of Timestamped Datasets Retrieved was on 07-07-2022:
# {'BL_DATE': ['20220706'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}
#
# Data Tracker's Retrieval Dates:
# dict_keys(['06-30-2022', '07-05-2022', '07-07-2022'])
#
# Data Tracker's Log of Timestamped Datasets (By Retrieval Date):
# {'06-30-2022': {'BL_DATE': ['20220623', '20220629'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220418'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-05-2022': {'BL_DATE': ['20220701'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220418'], 'INPUTDATA_ROOT_BMIC': ['20220207']}, '07-07-2022': {'BL_DATE': ['20220706'], 'INPUTDATA_ROOT': ['20220414'], 'INPUTDATA_ROOT_WW3': ['20220624'], 'INPUTDATA_ROOT_BMIC': ['20220207']}}

# %%
# Confirm: Keys of latest Retrieval Date Tracked by Data Tracker Bot
filter2tracker_ts_datasets.keys()
# Out:
# dict_keys(['INPUTDATA_ROOT', 'BL_DATE', 'INPUTDATA_ROOT_WW3', 'INPUTDATA_ROOT_BMIC'])

# %%
# Selected timestamp dataset of the latest rettrival date to transfer 
# from RDHPCS on-disk to cloud as tracked by data tracker bot
filter2tracker_ts_datasets
# Out:
# defaultdict(list,
#             {'INPUTDATA_ROOT': ['input-data-20220414/WW3_input_data_20220624/mesh.glo_1deg.nc',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.pointsatmw',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.glo_15mxt',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.gsh_15m',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.mx100',
#               'input-data-20220414/WW3_input_data_20220624/mesh.gwes_30m.nc',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.natl_6m',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.glo_1deg',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.mx050',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.aoc_9km',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.mx025',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.points',
#               'input-data-20220414/WW3_input_data_20220624/rmp_src_to_dst_conserv_002_001.nc',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.gwes_30m',
#               'input-data-20220414/WW3_input_data_20220624/wind.natl_6m',
#               'input-data-20220414/WW3_input_data_20220624/mesh.hafs.nc',
#               'input-data-20220414/WW3_input_data_20220624/rmp_src_to_dst_conserv_003_001.nc',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.mx025lite',
#               'input-data-20220414/WW3_input_data_20220624/mod_def.gnh_10m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_15mxt',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.ant_9km',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_2deg',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025obs0',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_5deg',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_1deg',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gwes_30m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.points',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx100obs0',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/machine-setup.sh',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gnh_10m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/creategridfiles.sh',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_30m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.gsh_15m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx025lite',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.glo_10m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.aoc_9km',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.natl_6m',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.pointsatmw',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx050obs0',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx050',
#               'input-data-20220414/WW3_input_data_20220624/createmoddefs/ww3_grid.inp.mx100',
#               'input-data-20220414/fv3_regional_c768/INPUT/grid.tile7.halo4.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/oro_data.tile7.halo4.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/sfc_data.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_ctrl.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_grid.tile7.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_oro_data.tile7.halo4.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_data.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_mosaic.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/grid_spec.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/sfc_data.tile7.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_data.tile7.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.000.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.006.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_grid.tile7.halo4.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.018.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_grid.tile7.halo3.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.012.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/oro_data.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/C768_oro_data.tile7.halo0.nc',
#               'input-data-20220414/fv3_regional_c768/INPUT/gfs_bndy.tile7.024.nc',
#               'input-data-20220414/FV3_input_data/qr_acr_qs',
#               'input-data-20220414/FV3_input_data/global_soiltype.statsgo.t126.384.190.rg.grb',
#               'input-data-20220414/FV3_input_data/qr_acr_qg',
#               'input-data-20220414/FV3_input_data/ugwp_c384_tau.nc',
#               'input-data-20220414/FV3_input_data/SOILPARM.TBL',
#               'input-data-20220414/FV3_input_data/global_mxsnoalb.uariz.t126.384.190.rg.grb',
#               'input-data-20220414/FV3_input_data/global_slmask.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data/DETAMPNEW_DATA.expanded_rain_LE',
#               'input-data-20220414/FV3_input_data/DETAMPNEW_DATA_LE',
#               'input-data-20220414/FV3_input_data/global_soilmgldas.t126.384.190.grb',
#               'input-data-20220414/FV3_input_data/GENPARM.TBL',
#               'input-data-20220414/FV3_input_data/global_snowfree_albedo.bosu.t126.384.190.rg.grb',
#               'input-data-20220414/FV3_input_data/global_soilmgldas.statsgo.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data/global_vegtype.igbp.t126.384.190.rg.grb',
#               'input-data-20220414/FV3_input_data/VEGPARM.TBL',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127_mx100/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/grid_spec.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ss.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_mosaic.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/C96_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT_L127/oro_data_ls.tile2.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/ORO_FLAKE/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT/grid_spec.nc',
#               'input-data-20220414/FV3_input_data/INPUT/fv3_increment.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_ctrl.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT/C96_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data/INPUT/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data/INPUT/gfs_data.tile3.nc',
#               'input-data-20220414/MOM6_FIX/100/topo_edits_011818.nc',
#               'input-data-20220414/MOM6_FIX/100/layer_coord.nc',
#               'input-data-20220414/MOM6_FIX/100/ocean_mask.nc',
#               'input-data-20220414/MOM6_FIX/100/topog.nc',
#               'input-data-20220414/MOM6_FIX/100/interpolate_zgrid_40L.nc',
#               'input-data-20220414/MOM6_FIX/100/tidal_amplitude.nc',
#               'input-data-20220414/MOM6_FIX/100/atmos_mosaic_tile1Xocean_mosaic_tile1.nc',
#               'input-data-20220414/MOM6_FIX/100/land_mosaic_tile1Xocean_mosaic_tile1.nc',
#               'input-data-20220414/MOM6_FIX/100/ocean_hgrid.nc',
#               'input-data-20220414/MOM6_FIX/100/land_mask.nc',
#               'input-data-20220414/MOM6_FIX/100/seawifs_1998-2006_smoothed_2X.nc',
#               'input-data-20220414/MOM6_FIX/100/KH_background_2d.nc',
#               'input-data-20220414/MOM6_FIX/100/hycom1_75_800m.nc',
#               'input-data-20220414/MOM6_FIX/100/MOM_override',
#               'input-data-20220414/MOM6_FIX/100/vgrid_75_2m.nc',
#               'input-data-20220414/MOM6_FIX/100/ocean_mosaic.nc',
#               'input-data-20220414/MOM6_FIX/100/atmos_mosaic_tile1Xland_mosaic_tile1.nc',
#               'input-data-20220414/MOM6_FIX/100/ufs.topo_edits_011818.nc',
#               'input-data-20220414/MOM6_FIX/100/MOM_channels_SPEAR',
#               'input-data-20220414/MOM6_FIX/400/ocean_mask.nc',
#               'input-data-20220414/MOM6_FIX/400/layer_coord25.nc',
#               'input-data-20220414/MOM6_FIX/400/ocean_hgrid.nc',
#               'input-data-20220414/MOM6_FIX/400/hycom1_25.nc',
#               'input-data-20220414/MOM6_FIX/400/MOM_override',
#               'input-data-20220414/MOM6_FIX/400/ocean_topog.nc',
#               'input-data-20220414/MOM6_FIX/400/ocean_mosaic.nc',
#               'input-data-20220414/MOM6_FIX/050/layer_coord.nc',
#               'input-data-20220414/MOM6_FIX/050/ocean_mask.nc',
#               'input-data-20220414/MOM6_FIX/050/runoff.daitren.clim.720x576.v20180328.nc',
#               'input-data-20220414/MOM6_FIX/050/salt_restore_PHC2.720x576.v20180405.nc',
#               'input-data-20220414/MOM6_FIX/050/interpolate_zgrid_40L.nc',
#               'input-data-20220414/MOM6_FIX/050/hash.md5',
#               'input-data-20220414/MOM6_FIX/050/tidal_amplitude.nc',
#               'input-data-20220414/MOM6_FIX/050/seawifs-clim-1997-2010.720x576.v20180328.nc',
#               'input-data-20220414/MOM6_FIX/050/land_mosaic_tile1Xocean_mosaic_tile1.nc',
#               'input-data-20220414/MOM6_FIX/050/ocean_hgrid.nc',
#               'input-data-20220414/MOM6_FIX/050/README.md',
#               'input-data-20220414/MOM6_FIX/050/land_mask.nc',
#               'input-data-20220414/MOM6_FIX/050/basin_codes.nc',
#               'input-data-20220414/MOM6_FIX/050/ocean_static.nc',
#               'input-data-20220414/MOM6_FIX/050/hycom1_75_800m.nc',
#               'input-data-20220414/MOM6_FIX/050/MOM_layout',
#               'input-data-20220414/MOM6_FIX/050/MOM_override',
#               'input-data-20220414/MOM6_FIX/050/ocean_topog.nc',
#               'input-data-20220414/MOM6_FIX/050/runoff.daitren.iaf.720x576.v20180328.nc',
#               'input-data-20220414/MOM6_FIX/050/geothermal_davies2013_v1.nc',
#               'input-data-20220414/MOM6_FIX/050/ocean_mosaic.nc',
#               'input-data-20220414/MOM6_FIX/050/MOM_channels_global_025',
#               'input-data-20220414/MOM6_FIX/025/layer_coord.nc',
#               'input-data-20220414/MOM6_FIX/025/ocean_mask.nc',
#               'input-data-20220414/MOM6_FIX/025/topog.nc',
#               'input-data-20220414/MOM6_FIX/025/interpolate_zgrid_40L.nc',
#               'input-data-20220414/MOM6_FIX/025/ocean_hgrid.nc',
#               'input-data-20220414/MOM6_FIX/025/tidal_amplitude.v20140616.nc',
#               'input-data-20220414/MOM6_FIX/025/hycom1_75_800m.nc',
#               'input-data-20220414/MOM6_FIX/025/MOM_layout',
#               'input-data-20220414/MOM6_FIX/025/MOM_override',
#               'input-data-20220414/MOM6_FIX/025/runoff.daitren.clim.1440x1080.v20180328.nc',
#               'input-data-20220414/MOM6_FIX/025/ocean_topog.nc',
#               'input-data-20220414/MOM6_FIX/025/seawifs-clim-1997-2010.1440x1080.v20180328.nc',
#               'input-data-20220414/MOM6_FIX/025/geothermal_davies2013_v1.nc',
#               'input-data-20220414/MOM6_FIX/025/ocean_mosaic.nc',
#               'input-data-20220414/MOM6_FIX/025/All_edits.nc',
#               'input-data-20220414/MOM6_FIX/025/MOM_channels_global_025',
#               'input-data-20220414/FV3_input_data_gsd/freezeH2O.dat',
#               'input-data-20220414/FV3_input_data_gsd/CCN_ACTIVATE.BIN',
#               'input-data-20220414/FV3_input_data_gsd/thompson_tables_precomp.sl',
#               'input-data-20220414/FV3_input_data_gsd/qr_acr_qsV2.dat',
#               'input-data-20220414/FV3_input_data_gsd/qr_acr_qg.dat',
#               'input-data-20220414/FV3_input_data_gsd/qr_acr_qgV2.dat',
#               'input-data-20220414/FV3_input_data_gsd/qr_acr_qs.dat',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_ctrl.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/grid_spec.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/plot_nifa.ncl',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/C96_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/plot_nwfa.ncl',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/FV3_input_data_C96_with_aerosols/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile1.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile2.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile4.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ss.tile5.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile3.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile6.nc',
#               'input-data-20220414/FV3_input_data_gsd/drag_suite/oro_data_ls.tile2.nc',
#               'input-data-20220414/DOCN_MOM6_input_data/hycom_201908_surf_nolev.nc',
#               'input-data-20220414/DOCN_MOM6_input_data/hat10_210129_ESMFmesh_py.nc',
#               'input-data-20220414/FV3_regional_input_data/global_slmask.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_regional_input_data/freezeH2O.dat',
#               'input-data-20220414/FV3_regional_input_data/CCN_ACTIVATE.BIN',
#               'input-data-20220414/FV3_regional_input_data/thompson_tables_precomp.sl',
#               'input-data-20220414/FV3_regional_input_data/qr_acr_qsV2.dat',
#               'input-data-20220414/FV3_regional_input_data/global_soilmgldas.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_regional_input_data/qr_acr_qg.dat',
#               'input-data-20220414/FV3_regional_input_data/global_snoclim.1.875.grb',
#               'input-data-20220414/FV3_regional_input_data/qr_acr_qgV2.dat',
#               'input-data-20220414/FV3_regional_input_data/qr_acr_qs.dat',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.airtmp.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.vapmix.b',
#               'input-data-20220414/HYCOM_regional_input_data/patch.input',
#               'input-data-20220414/HYCOM_regional_input_data/relax.ssh.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.chl.b',
#               'input-data-20220414/HYCOM_regional_input_data/veldf2.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.radflx.a',
#               'input-data-20220414/HYCOM_regional_input_data/ports.input',
#               'input-data-20220414/HYCOM_regional_input_data/hycom_settings',
#               'input-data-20220414/HYCOM_regional_input_data/regional.grid.a',
#               'input-data-20220414/HYCOM_regional_input_data/restart_in.a',
#               'input-data-20220414/HYCOM_regional_input_data/thkdf4.b',
#               'input-data-20220414/HYCOM_regional_input_data/blkdat.input',
#               'input-data-20220414/HYCOM_regional_input_data/iso.sigma.a',
#               'input-data-20220414/HYCOM_regional_input_data/iso.sigma.b',
#               'input-data-20220414/HYCOM_regional_input_data/tbaric.b',
#               'input-data-20220414/HYCOM_regional_input_data/regional.depth.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.presur.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.wndspd.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.surtmp.b',
#               'input-data-20220414/HYCOM_regional_input_data/relax.rmu.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.mslprs.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.taunwd.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.shwflx.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.shwflx.b',
#               'input-data-20220414/HYCOM_regional_input_data/veldf4.b',
#               'input-data-20220414/HYCOM_regional_input_data/regional.grid.b',
#               'input-data-20220414/HYCOM_regional_input_data/relax.rmu.b',
#               'input-data-20220414/HYCOM_regional_input_data/regional.depth.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.vapmix.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.rivers.a',
#               'input-data-20220414/HYCOM_regional_input_data/relax.ssh.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.surtmp.a',
#               'input-data-20220414/HYCOM_regional_input_data/veldf4.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.rivers.b',
#               'input-data-20220414/HYCOM_regional_input_data/tbaric.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.presur.b',
#               'input-data-20220414/HYCOM_regional_input_data/thkdf4.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.airtmp.b',
#               'input-data-20220414/HYCOM_regional_input_data/veldf2.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.mslprs.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.radflx.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.chl.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.tauewd.b',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.precip.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.tauewd.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.taunwd.b',
#               'input-data-20220414/HYCOM_regional_input_data/limits',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.wndspd.a',
#               'input-data-20220414/HYCOM_regional_input_data/forcing.precip.b',
#               'input-data-20220414/HYCOM_regional_input_data/restart_in.b',
#               'input-data-20220414/FV3_fix/sfc_emissivity_idx.txt',
#               'input-data-20220414/FV3_fix/solarconstant_noaa_an.txt',
#               'input-data-20220414/FV3_fix/global_h2oprdlos.f77',
#               'input-data-20220414/FV3_fix/global_albedo4.1x1.grb',
#               'input-data-20220414/FV3_fix/global_glacier.2x2.grb',
#               'input-data-20220414/FV3_fix/global_slope.1x1.grb',
#               'input-data-20220414/FV3_fix/RTGSST.1982.2012.monthly.clim.grb',
#               'input-data-20220414/FV3_fix/global_zorclim.1x1.grb',
#               'input-data-20220414/FV3_fix/freezeH2O.dat',
#               'input-data-20220414/FV3_fix/global_vegfrac.0.144.decpercent.grb',
#               'input-data-20220414/FV3_fix/CCN_ACTIVATE.BIN',
#               'input-data-20220414/FV3_fix/IMS-NIC.blended.ice.monthly.clim.grb',
#               'input-data-20220414/FV3_fix/qr_acr_qsV2.dat',
#               'input-data-20220414/FV3_fix/global_snoclim.1.875.grb',
#               'input-data-20220414/FV3_fix/global_shdmin.0.144x0.144.grb',
#               'input-data-20220414/FV3_fix/qr_acr_qgV2.dat',
#               'input-data-20220414/FV3_fix/global_tg3clim.2.6x1.5.grb',
#               'input-data-20220414/FV3_fix/global_shdmax.0.144x0.144.grb',
#               'input-data-20220414/FV3_fix/aerosol.dat',
#               'input-data-20220414/FV3_fix/global_maxice.2x2.grb',
#               'input-data-20220414/FV3_fix/seaice_newland.grb',
#               'input-data-20220414/FV3_fix/global_o3prdlos.f77',
#               'input-data-20220414/FV3_fix/CFSR.SEAICE.1982.2012.monthly.clim.grb',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2019.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2020.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2014.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2018.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2017.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2016.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2011.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2009.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_glob.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2013.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2021.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2012.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2monthlycyc.txt',
#               'input-data-20220414/FV3_fix/fix_co2_proj/co2historicaldata_2015.txt',
#               'input-data-20220414/FV3_input_data384/global_mxsnoalb.uariz.t766.1536.768.rg.grb',
#               'input-data-20220414/FV3_input_data384/global_soiltype.statsgo.t766.1536.768.rg.grb',
#               'input-data-20220414/FV3_input_data384/global_slmask.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data384/global_soilmgldas.t766.1536.768.grb',
#               'input-data-20220414/FV3_input_data384/global_snoclim.1.875.grb',
#               'input-data-20220414/FV3_input_data384/global_snowfree_albedo.bosu.t766.1536.768.rg.grb',
#               'input-data-20220414/FV3_input_data384/global_soilmgldas.statsgo.t766.1536.768.grb',
#               'input-data-20220414/FV3_input_data384/global_soilmgldas.statsgo.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data384/global_vegtype.igbp.t766.1536.768.rg.grb',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_mx025/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/grid_spec.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_mosaic.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ss.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/C384_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127/oro_data_ls.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/grid_spec.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/C384_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/grid_spec.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_increment3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_increment6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/coupler.res',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_srf_wnd.res.tile4.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile2.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/phy_data.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_tracer.res.tile3.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_core.res.tile5.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/fv_increment9.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/C384_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data384/INPUT_L127_GDAS/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data768/global_mxsnoalb.uariz.t1534.3072.1536.rg.grb',
#               'input-data-20220414/FV3_input_data768/global_vegtype.igbp.t1534.3072.1536.rg.grb',
#               'input-data-20220414/FV3_input_data768/global_slmask.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data768/global_snowfree_albedo.bosu.t1534.3072.1536.rg.grb',
#               'input-data-20220414/FV3_input_data768/global_snoclim.1.875.grb',
#               'input-data-20220414/FV3_input_data768/global_soiltype.statsgo.t1534.3072.1536.rg.grb',
#               'input-data-20220414/FV3_input_data768/global_soilmgldas.statsgo.t1534.3072.1536.grb',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile4.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile5.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile5.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile4.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile4.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile2.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_ctrl.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile6.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile2.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile4.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile5.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile3.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile1.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/grid_spec.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile2.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile1.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile6.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile6.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile1.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile3.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/oro_data.tile3.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile1.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile5.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/sfc_data.tile6.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/gfs_data.tile3.nc',
#               'input-data-20220414/FV3_input_data768/INPUT_L127/C768_grid.tile2.nc',
#               'input-data-20220414/CICE_IC/100/cice_model_1.00.cpc.res_2011100100.nc',
#               'input-data-20220414/CICE_IC/100/cice_model_1.00.cpc.res_20210322.nc',
#               'input-data-20220414/CICE_IC/400/cice_model_4.00.cpc.res_20210322.nc',
#               'input-data-20220414/CICE_IC/050/cice_model_0.50.cpc.res_20210322.nc',
#               'input-data-20220414/CICE_IC/025/cice_model_0.25.cpc.res_2011100100.nc',
#               'input-data-20220414/CICE_IC/025/cice_model_0.25.cpc.res_20210322.nc',
#               'input-data-20220414/WW3_input_data_20211113/mesh.glo_1deg.nc',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_15mxt',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.gsh_15m',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.ant_9km',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.mx100',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.natl_6m',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_1deg',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.mx050',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.aoc_9km',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.mx025',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_2deg',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.points',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_30m',
#               'input-data-20220414/WW3_input_data_20211113/rmp_src_to_dst_conserv_002_001.nc',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.gwes_30m',
#               'input-data-20220414/WW3_input_data_20211113/wind.natl_6m',
#               'input-data-20220414/WW3_input_data_20211113/mesh.hafs.nc',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_5deg',
#               'input-data-20220414/WW3_input_data_20211113/rmp_src_to_dst_conserv_003_001.nc',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.glo_10m',
#               'input-data-20220414/WW3_input_data_20211113/mod_def.gnh_10m',
#               'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.glo_15mxt',
#               'input-data-20220414/WW3_input_data_20211113/createmoddefs/ww3_grid.inp.ant_9km',
# ...
#               'BM_IC-20220207/2013040100/wav_p7.2/gwes_30m/20130401.000000.restart.gwes_30m',
#               'BM_IC-20220207/2013040100/cpc/cice5_model_0.25.res_2013040100.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013040100/p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013070100/wav_p8c/mx025/20130701.000000.restart.mx025',
#               'BM_IC-20220207/2013070100/mom6_da/MOM.res.nc',
#               'BM_IC-20220207/2013070100/mom6_da/MOM.res_2.nc',
#               'BM_IC-20220207/2013070100/mom6_da/MOM.res_4.nc',
#               'BM_IC-20220207/2013070100/mom6_da/MOM.res_3.nc',
#               'BM_IC-20220207/2013070100/mom6_da/MOM.res_1.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013070100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013070100/wav_p7.2/gwes_30m/20130701.000000.restart.gwes_30m',
#               'BM_IC-20220207/2013070100/cpc/cice5_model_0.25.res_2013070100.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013070100/p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013010100/wav_p8c/mx025/20130101.000000.restart.mx025',
#               'BM_IC-20220207/2013010100/mom6_da/MOM.res.nc',
#               'BM_IC-20220207/2013010100/mom6_da/MOM.res_2.nc',
#               'BM_IC-20220207/2013010100/mom6_da/MOM.res_4.nc',
#               'BM_IC-20220207/2013010100/mom6_da/MOM.res_3.nc',
#               'BM_IC-20220207/2013010100/mom6_da/MOM.res_1.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013010100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2013010100/wav_p7.2/gwes_30m/20130101.000000.restart.gwes_30m',
#               'BM_IC-20220207/2013010100/cpc/cice5_model_0.25.res_2013010100.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2013010100/p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p8c/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p8a/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2012040100/wav_p8c/mx025/20120401.000000.restart.mx025',
#               'BM_IC-20220207/2012040100/mom6_da/MOM.res.nc',
#               'BM_IC-20220207/2012040100/mom6_da/MOM.res_2.nc',
#               'BM_IC-20220207/2012040100/mom6_da/MOM.res_4.nc',
#               'BM_IC-20220207/2012040100/mom6_da/MOM.res_3.nc',
#               'BM_IC-20220207/2012040100/mom6_da/MOM.res_1.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2012040100/gfs_p7/C384_L127/INPUT/gfs_data.tile3.nc',
#               'BM_IC-20220207/2012040100/wav_p7.2/gwes_30m/20120401.000000.restart.gwes_30m',
#               'BM_IC-20220207/2012040100/cpc/cice5_model_0.25.res_2012040100.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile4.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_ctrl.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile2.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile4.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile5.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile2.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile6.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile1.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile3.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile1.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile5.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/sfc_data.tile6.nc',
#               'BM_IC-20220207/2012040100/p8c/C384_L127/INPUT/gfs_data.tile3.nc']})

# %% [markdown]
# ### Obtain directories for the datasets requested by the user.

# %%
# if __name__ == '__main__': 
    
#     # Module for extracting data from source.
#     from get_timestamp_data import GetTimestampData
    
#     # Establish locality of where the dataseta are sourced.
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
    
#     # Select timestamp dataset to transfer from RDHPCS on-disk to cloud
#     input_ts, bl_ts, ww3_input_ts, bmic_ts = [], ['develop-20220706'], ['WW3_input_data_20220624'], []
#     filter2specific_ts_datasets = GetTimestampData(orion_rt_data_dir, None).get_specific_ts_files(input_ts, bl_ts, ww3_input_ts, bmic_ts)
# filter2specific_ts_datasets.keys()

# %%
# # Selected timestamp dataset to transfer from RDHPCS on-disk to cloud
# filter2specific_ts_datasets

# %% [markdown]
# # Demo 2: Multipart Upload of Extracted Data to Cloud

# %% [markdown]
# ### Upload datasets tracked by the data tracker bot.

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, filter2tracker_ts_datasets, use_bucket='rt')
#     uploader_wrapper.upload_files2cloud()

# %% [markdown]
# ### Upload datasets by timestamps as requested by the user.
# - In this scenario, used when transferring data files required for the UFS-WM currently deployed in the CSPs.

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, filter2specific_ts_datasets, use_bucket='rt')
#     uploader_wrapper.upload_files2cloud()

# %% [markdown]
# # Consolidated Demo: Extract Data Localities & Upload to Cloud

# %% [markdown]
# ### Extract & upload datasets (input data + baseline data + IC data) as requested by the user.

# %%
# # Obtain directories & upload to cloud for the datasets requested by the user.
# from transfer_specific_data import TransferSpecificData
# input_ts, bl_ts, ww3_input_ts, bmic_ts = [], ['develop-20220706'], ['WW3_input_data_20220624'], []
# TransferSpecificData(input_ts, bl_ts, ww3_input_ts, bmic_ts, linked_home_dir="/home/schin/work", platform="orion")

# %% [markdown]
# ### Extract & upload datasets tracked by the data tracker bot.

# %%
# Obtain directories & upload to cloud for the latest retrieved set of timestamped datasets tracked by the data tracker bot.
from transfer_bot_data import TransferBotData
TransferBotData(linked_home_dir="/home/schin/work", platform="orion")

# %% [markdown]
# # Demo: Upload a Single Data File of Interest

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
    
#     # Upload a Single Data File of Interest
#     file_dir = 'input-data-20211210/fv3_regional_c768/INPUT/grid.tile7.halo4.nc'
#     uploader_wrapper.upload_single_file(file_dir)

# %% [markdown]
# # Demo: Delete a File

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     file_dir = 'input-data-20211210/fv3_regional_c768/INPUT/grid.tile7.halo4.nc'
#     key_path = file_dir
#     uploader_wrapper.purge(key_path)

# %% [markdown]
# # Demo: Delete Objects with Key Prefix

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     linked_home_dir = "/home/schin/work"
#     orion_rt_data_dir = linked_home_dir + "/noaa/nems/emc.nemspara/RT/NEMSfv3gfs/"
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     key_prefix = 'develop-20220511'
#     uploader_wrapper.purge_by_keyprefix(key_prefix)

# %% [markdown]
# # Demo: Copy Objects & Delete with Key Prefix
# AWS CLI copies the objects to the target folder and then removes the original file. There is no “move” action in S3.

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     source_key_path = '####' 
#     new_key_path = '###'
#     uploader_wrapper.rename_s3_keys(source_key_path, new_key_path)

# %% [markdown]
# # Demo: Get List of All Keys in UFS RT S3 Bucket

# %%
# if __name__ == '__main__': 
#     from progress_bar import ProgressPercentage
#     from upload_data import UploadData
#     uploader_wrapper = UploadData(orion_rt_data_dir, file_relative_dirs=None, use_bucket='rt')
#     all_bucket_objects = uploader_wrapper.get_all_s3_keys()
# all_bucket_objects

# %%
# Write list to text file and save to directory
# with open('filename].[file_format]', 'w') as f:
#     for item in all_bucket_objects:
#         f.write("%s\n" % item)
